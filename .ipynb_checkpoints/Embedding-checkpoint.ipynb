# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# df = pd.read_parquet("./data/data.parquet")

# %%
unique_ids = set(df.id.unique())

# %%
# ref_in_df = df.references.map(lambda x: [x in unique_ids for x in x])

# %%
df['refs'] = df.references.map(lambda x: [x for x in x if x in unique_ids])

# %%
ref_in_df.map(lambda x: np.mean(x)).hist()
# Out:
# <AxesSubplot: >

# %%
plt.hist(np.log(refs_only_in_df.map(lambda x: len(x)) + 1))
# Out:
# (array([3.636610e+05, 4.838100e+05, 1.023479e+06, 1.113577e+06,
#         5.359270e+05, 6.515300e+04, 5.933000e+03, 5.070000e+02,
#         2.600000e+01, 7.000000e+00]),
#  array([0.        , 0.74430784, 1.48861567, 2.23292351, 2.97723135,
#         3.72153919, 4.46584702, 5.21015486, 5.9544627 , 6.69877054,
#         7.44307837]),
#  <BarContainer object of 10 artists>)

# %%
df['refs']
